# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# A/B Testing - Step by Step Hypothesis Testing\n",
    "Basado en el notebook de Kaggle."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "from scipy import stats\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "df = pd.read_csv('data/ab_data.csv')\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "control = df[df['group'] == 'control']\n",
    "treatment = df[df['group'] == 'treatment']\n",
    "\n",
    "conv_control = control['converted'].mean()\n",
    "conv_treatment = treatment['converted'].mean()\n",
    "\n",
    "print(f\"Control conversion rate: {conv_control:.4f}\")\n",
    "print(f\"Treatment conversion rate: {conv_treatment:.4f}\")\n",
    "\n",
    "t_stat, p_val = stats.ttest_ind(control['converted'], treatment['converted'])\n",
    "print(f\"t-statistic: {t_stat:.4f}, p-value: {p_val:.4f}\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.x"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
